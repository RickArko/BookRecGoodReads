# %%
# %import autoreload
# %autoreload 2
# %cd ..

# %% [markdown]
# # Goodreads User-Book Interactions

# %%
import gzip
import json
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:,}'.format
# %matplotlib inline

# %%
DIR = './'
PATH_IN = os.path.join(DIR, 'goodreads_interactions.csv')
df_interactions = pd.read_csv(PATH_IN)
